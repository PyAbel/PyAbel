# %%
# %matplotlib inline
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
from abel.hansenlaw import *

# %%
im = np.loadtxt('../examples/data/O2-ANU1024.txt.bz2')

# %%
plt.imshow(im)

# %%
recon,speed = iabel_hansenlaw(im,quad=(False,False,False,False),calc_speeds=True,verbose=True)
# Out:
# HL: Calculating inverse Abel transform:  image size 1024x1024
# HL: Individual quadrants
# HL: Calculating inverse Abel transform ...
# 0.72 seconds
# Generating speed distribution ...
# 0.43 seconds

# %%
plt.imshow(recon,vmin=0,vmax=2.0)

# %%
plt.xlabel("speed")
plt.ylabel("yield")
plt.axis(xmax=500,ymin=-20,ymax=300)
plt.plot(speed)
